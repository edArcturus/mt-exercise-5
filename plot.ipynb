# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import csv

# %%
csv_text = """beam,bleu
1,8.0
2,8.3
3,8.3
4,8.3
5,8.2
6,8.2
7,8.2
8,8.2
10,8.1
15,8.0
"""

# %%
data = np.loadtxt('eval.csv', delimiter=',', dtype=str)

# %%
df = pd.read_csv('eval.csv')

# %%
sns.set()
df.plot(x='beam', y='bleu', xlabel='Beam size', ylabel='BLEU score')
plt.savefig('plot.png', dpi=300)
